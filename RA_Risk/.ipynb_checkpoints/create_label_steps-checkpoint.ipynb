# %%
#1.  import the raw data, note whether rul is included, if not 

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

save_path = '/home/peng/Documents/Project_C/Turbofan/Dataset/'
names = xrange(0,26)
#df = pd.read_csv(save_path + 'train_FD001_rul.txt',header=0)
df = pd.read_csv(save_path + 'train_FD001.txt',delim_whitespace=True, names=names, header=None)

#print df
#print df.describe()

# create a nan column to store the labels
df['target_easy']=np.nan
#df['ratio']=np.nan
print df
# Out:
#          0    1       2       3      4       5       6        7        8  \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# 5        1    6 -0.0043 -0.0001  100.0  518.67  642.10  1584.47  1398.37
# 6        1    7  0.0010  0.0001  100.0  518.67  642.48  1592.32  1397.77
# 7        1    8 -0.0034  0.0003  100.0  518.67  642.56  1582.96  1400.97
# 8        1    9  0.0008  0.0001  100.0  518.67  642.12  1590.98  1394.80
# 9        1   10 -0.0033  0.0001  100.0  518.67  641.71  1591.24  1400.46
# 10       1   11  0.0018 -0.0003  100.0  518.67  642.28  1581.75  1400.64
# 11       1   12  0.0016  0.0002  100.0  518.67  642.06  1583.41  1400.15
# 12       1   13 -0.0019  0.0004  100.0  518.67  643.07  1582.19  1400.83
# 13       1   14  0.0009 -0.0000  100.0  518.67  642.35  1592.95  1399.16
# 14       1   15 -0.0018 -0.0003  100.0  518.67  642.43  1583.82  1402.13
# 15       1   16  0.0006  0.0005  100.0  518.67  642.13  1587.98  1404.50
# 16       1   17  0.0002  0.0002  100.0  518.67  642.58  1584.96  1399.95
# 17       1   18 -0.0031 -0.0001  100.0  518.67  642.62  1591.04  1396.12
# 18       1   19  0.0032 -0.0003  100.0  518.67  641.79  1587.56  1400.35
# 19       1   20 -0.0037  0.0001  100.0  518.67  643.04  1581.11  1405.23
# 20       1   21 -0.0012  0.0001  100.0  518.67  642.37  1586.07  1398.13
# 21       1   22  0.0002  0.0000  100.0  518.67  642.77  1592.93  1400.57
# 22       1   23  0.0034 -0.0003  100.0  518.67  642.14  1588.19  1394.75
# 23       1   24 -0.0010  0.0003  100.0  518.67  642.38  1590.83  1398.81
# 24       1   25  0.0023 -0.0004  100.0  518.67  642.77  1594.10  1399.39
# 25       1   26  0.0000  0.0002  100.0  518.67  642.16  1589.08  1396.07
# 26       1   27 -0.0012 -0.0004  100.0  518.67  642.44  1590.47  1401.84
# 27       1   28 -0.0024  0.0005  100.0  518.67  642.35  1582.84  1399.13
# 28       1   29  0.0012 -0.0001  100.0  518.67  641.91  1584.83  1400.99
# 29       1   30 -0.0022  0.0000  100.0  518.67  642.20  1593.52  1396.08
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20601  100  171 -0.0005 -0.0004  100.0  518.67  643.05  1593.56  1420.48
# 20602  100  172 -0.0037  0.0001  100.0  518.67  642.97  1602.35  1424.93
# 20603  100  173  0.0006  0.0004  100.0  518.67  643.40  1595.53  1418.63
# 20604  100  174  0.0011  0.0002  100.0  518.67  642.91  1602.24  1425.52
# 20605  100  175 -0.0013 -0.0005  100.0  518.67  642.85  1602.03  1416.24
# 20606  100  176 -0.0017 -0.0003  100.0  518.67  643.33  1601.44  1421.40
# 20627  14.62     ...       2388.22  8136.50  8.5139  0.03  395  2388  100.0
# 20628  14.62     ...       2388.24  8141.05  8.5646  0.03  398  2388  100.0
# 20629  14.62     ...       2388.23  8139.29  8.5389  0.03  395  2388  100.0
# 20630  14.62     ...       2388.26  8137.33  8.5036  0.03  396  2388  100.0
#
#           24       25  target_easy
# 0      39.06  23.4190          NaN
# 1      39.00  23.4236          NaN
# 2      38.95  23.3442          NaN
# 3      38.88  23.3739          NaN
# 4      38.90  23.4044          NaN
# 5      38.98  23.3669          NaN
# 6      39.10  23.3774          NaN
# 7      38.97  23.3106          NaN
# 8      39.05  23.4066          NaN
# 9      38.95  23.4694          NaN
# 10     38.94  23.4787          NaN
# 11     39.06  23.3660          NaN
# 12     38.93  23.2757          NaN
# 13     39.18  23.3826          NaN
# 14     38.99  23.3500          NaN
# 15     38.97  23.4550          NaN
# 16     38.81  23.3319          NaN
# 17     38.89  23.3987          NaN
# 18     38.80  23.3464          NaN
# 19     39.03  23.4220          NaN
# 20     39.09  23.3101          NaN
# 21     38.92  23.3792          NaN
# 22     38.94  23.4562          NaN
# 23     39.00  23.3696          NaN
# 24     38.95  23.4288          NaN
# 25     38.86  23.4149          NaN
# 26     38.99  23.4472          NaN
# 27     39.01  23.2841          NaN
# 28     38.93  23.3597          NaN
# 29     39.05  23.4110          NaN
# ...      ...      ...          ...
# 20601  38.81  23.1513          NaN
# 20602  38.49  23.1922          NaN
# 20603  38.42  23.1793          NaN
# 20604  38.80  23.1784          NaN
# 20605  38.54  23.0713          NaN
# 20606  38.46  23.1020          NaN
# 20607  38.60  23.0352          NaN
# 20608  38.55  23.2252          NaN
# 20609  38.62  23.1685          NaN
# 20610  38.54  23.2345          NaN
# 20611  38.52  23.1774          NaN
# 20612  38.41  23.1289          NaN
# 20613  38.49  23.0709          NaN
# 20614  38.44  23.1229          NaN
# 20615  38.60  23.2127          NaN
# 20616  38.51  23.1173          NaN
# 20617  38.67  23.2308          NaN
# 20618  38.36  23.0552          NaN
# 20619  38.65  23.0591          NaN
# 20620  38.42  23.0603          NaN
# 20621  38.39  23.1218          NaN
# 20622  38.56  23.0770          NaN
# 20623  38.47  23.0230          NaN
# 20624  38.38  23.1324          NaN
# 20625  38.14  23.1923          NaN
# 20626  38.49  22.9735          NaN
# 20627  38.30  23.1594          NaN
# 20628  38.44  22.9333          NaN
# 20629  38.29  23.0640          NaN
# 20630  38.37  23.0522          NaN
#
# [20631 rows x 27 columns]

# %%
## create label for ratio, the ratio of the length

for i in xrange(1, df[0].values.max()+1):
    
    #ratio_list.append(df[df[0]==i][1]/ len(df[df[0]==i]))
    #df[df[0]==i]['ratio']=(df[df[0]==i][1]/ len(df[df[0]==i]))
    df.loc[((df[0] == i) ), 'ratio']= df[df[0]==i][1]/ len(df[df[0]==i])
    #print i

# %%
# label the top 30 and bottom 30 for the class healthy and failed 

for i in xrange(1, df[0].values.max()+1):
    df['target_easy'][df[df[0]==i].head(50).index.values] = 0
    df['target_easy'][df[df[0]==i].tail(50).index.values] = 1

# %%
#label two disc classes ratio


for i in xrange(1, df[0].values.max()+1):
    length = len(df[df[0]==i])
        
    #df[df['A'] > 2]['B'] = new_val  # new_val not set in df

    #df.loc[df[0] == i, 'target_easy'] []= new_val
    
    df.loc[((df[0] == i) & (df[1]<= int(0.8*length))), 'target_easy']=0
    
#    df.loc[((df[0] == i) & ( (df[1]>=int(0.4*length) ) & (df[1]<= int(0.6*length)))),
#           'target_easy']=1
    
    #df.loc[((df[0] == i) & ( (df[1]>=int(0.5*length) ) & (df[1]<= int(0.75*length)))),
    #       'target_easy']=2
    
    df.loc[((df[0] == i) & (df[1]>= int(0.8*length))), 'target_easy']=1

# %%
#label three disc classes_ not ratio

for i in xrange(1, df[0].values.max()+1):

    
    length = len(df[df[0]==i])
    
    #df[df['A'] > 2]['B'] = new_val  # new_val not set in df

    #df.loc[df[0] == i, 'target_easy'] []= new_val
    
    df.loc[((df[0] == i) & (df[1]<= (length- 220))), 'target_easy']=0
    
    df.loc[((df[0] == i) & ( (df[1]>=(length - 200) ) & (df[1]<=(length - 150)))),
           'target_easy']=1
    
    df.loc[((df[0] == i) & ( (df[1]>=(length - 125) ) & (df[1]<= (length - 75)))),
           'target_easy']=2
    
    df.loc[((df[0] == i) & (df[1]>= (length - 50))), 'target_easy']=3

# %%
#label three disc classes

for i in xrange(1, df[0].values.max()+1):
    length = len(df[df[0]==i])
    
    
    
    #df[df['A'] > 2]['B'] = new_val  # new_val not set in df

    #df.loc[df[0] == i, 'target_easy'] []= new_val
    
    df.loc[((df[0] == i) & (df[1]<= int(0.2*length))), 'target_easy']=0
    
    df.loc[((df[0] == i) & ( (df[1]>=int(0.4*length) ) & (df[1]<= int(0.6*length)))),
           'target_easy']=1
    
    #df.loc[((df[0] == i) & ( (df[1]>=int(0.5*length) ) & (df[1]<= int(0.75*length)))),
    #       'target_easy']=2
    
    df.loc[((df[0] == i) & (df[1]>= int(0.8*length))), 'target_easy']=2

# %%
#label three classes

for i in xrange(1, df[0].values.max()+1):

    
    length = len(df[df[0]==i])
    
    #df[df['A'] > 2]['B'] = new_val  # new_val not set in df

    #df.loc[df[0] == i, 'target_easy'] []= new_val
    
    df.loc[((df[0] == i) & (df[1]<= int(0.333*length))), 'target_easy']=0
    
    df.loc[((df[0] == i) & ( (df[1]>=int(0.333*length) ) & (df[1]<= int(0.666*length)))),
           'target_easy']=1
    
    #df.loc[((df[0] == i) & ( (df[1]>=int(0.5*length) ) & (df[1]<= int(0.75*length)))),
    #       'target_easy']=2
    
    df.loc[((df[0] == i) & (df[1]>= int(0.666*length))), 'target_easy']=2

# %%
# label four classes

for i in xrange(1, df[0].values.max()+1):

    
    length = len(df[df[0]==i])
    
    #df[df['A'] > 2]['B'] = new_val  # new_val not set in df

    #df.loc[df[0] == i, 'target_easy'] []= new_val
    
    df.loc[((df[0] == i) & (df[1]<= int(0.25*length))), 'target_easy']=0
    
    df.loc[((df[0] == i) & ( (df[1]>=int(0.25*length) ) & (df[1]<= int(0.5*length)))),
           'target_easy']=1
    
    df.loc[((df[0] == i) & ( (df[1]>=int(0.5*length) ) & (df[1]<= int(0.75*length)))),
           'target_easy']=2
    
    df.loc[((df[0] == i) & (df[1]>= int(0.75*length))), 'target_easy']=3

# %%
print df
# Out:
#          0    1       2       3      4       5       6        7        8  \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# 5        1    6 -0.0043 -0.0001  100.0  518.67  642.10  1584.47  1398.37
# 6        1    7  0.0010  0.0001  100.0  518.67  642.48  1592.32  1397.77
# 7        1    8 -0.0034  0.0003  100.0  518.67  642.56  1582.96  1400.97
# 8        1    9  0.0008  0.0001  100.0  518.67  642.12  1590.98  1394.80
# 9        1   10 -0.0033  0.0001  100.0  518.67  641.71  1591.24  1400.46
# 10       1   11  0.0018 -0.0003  100.0  518.67  642.28  1581.75  1400.64
# 11       1   12  0.0016  0.0002  100.0  518.67  642.06  1583.41  1400.15
# 12       1   13 -0.0019  0.0004  100.0  518.67  643.07  1582.19  1400.83
# 13       1   14  0.0009 -0.0000  100.0  518.67  642.35  1592.95  1399.16
# 14       1   15 -0.0018 -0.0003  100.0  518.67  642.43  1583.82  1402.13
# 15       1   16  0.0006  0.0005  100.0  518.67  642.13  1587.98  1404.50
# 16       1   17  0.0002  0.0002  100.0  518.67  642.58  1584.96  1399.95
# 17       1   18 -0.0031 -0.0001  100.0  518.67  642.62  1591.04  1396.12
# 18       1   19  0.0032 -0.0003  100.0  518.67  641.79  1587.56  1400.35
# 19       1   20 -0.0037  0.0001  100.0  518.67  643.04  1581.11  1405.23
# 20       1   21 -0.0012  0.0001  100.0  518.67  642.37  1586.07  1398.13
# 21       1   22  0.0002  0.0000  100.0  518.67  642.77  1592.93  1400.57
# 22       1   23  0.0034 -0.0003  100.0  518.67  642.14  1588.19  1394.75
# 23       1   24 -0.0010  0.0003  100.0  518.67  642.38  1590.83  1398.81
# 24       1   25  0.0023 -0.0004  100.0  518.67  642.77  1594.10  1399.39
# 25       1   26  0.0000  0.0002  100.0  518.67  642.16  1589.08  1396.07
# 26       1   27 -0.0012 -0.0004  100.0  518.67  642.44  1590.47  1401.84
# 27       1   28 -0.0024  0.0005  100.0  518.67  642.35  1582.84  1399.13
# 28       1   29  0.0012 -0.0001  100.0  518.67  641.91  1584.83  1400.99
# 29       1   30 -0.0022  0.0000  100.0  518.67  642.20  1593.52  1396.08
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20601  100  171 -0.0005 -0.0004  100.0  518.67  643.05  1593.56  1420.48
# 20602  100  172 -0.0037  0.0001  100.0  518.67  642.97  1602.35  1424.93
# 20603  100  173  0.0006  0.0004  100.0  518.67  643.40  1595.53  1418.63
# 20604  100  174  0.0011  0.0002  100.0  518.67  642.91  1602.24  1425.52
# 20605  100  175 -0.0013 -0.0005  100.0  518.67  642.85  1602.03  1416.24
# 20606  100  176 -0.0017 -0.0003  100.0  518.67  643.33  1601.44  1421.40
# 18     14.62    ...     8129.13  8.4321  0.03  391  2388  100.0  38.80
# 19     14.62    ...     8129.71  8.4210  0.03  392  2388  100.0  39.03
# 20     14.62    ...     8134.02  8.4049  0.03  392  2388  100.0  39.09
# 21     14.62    ...     8130.41  8.4034  0.03  392  2388  100.0  38.92
# 22     14.62    ...     8127.90  8.4240  0.03  392  2388  100.0  38.94
# 23     14.62    ...     8133.88  8.3891  0.03  392  2388  100.0  39.00
# 24     14.62    ...     8136.61  8.3917  0.03  393  2388  100.0  38.95
# 25     14.62    ...     8131.15  8.4260  0.03  394  2388  100.0  38.86
# 26     14.62    ...     8134.60  8.4046  0.03  393  2388  100.0  38.99
# 27     14.62    ...     8127.30  8.4323  0.03  390  2388  100.0  39.01
# 28     14.62    ...     8133.06  8.4189  0.03  393  2388  100.0  38.93
# 29     14.62    ...     8137.86  8.4065  0.03  390  2388  100.0  39.05
# ...      ...    ...         ...     ...   ...  ...   ...    ...    ...
# 20601  14.62    ...     8144.03  8.5085  0.03  396  2388  100.0  38.81
# 20602  14.62    ...     8142.08  8.4970  0.03  394  2388  100.0  38.49
# 20603  14.62    ...     8143.13  8.4856  0.03  393  2388  100.0  38.42
# 20604  14.62    ...     8143.61  8.4990  0.03  395  2388  100.0  38.80
# 20605  14.62    ...     8140.88  8.4851  0.03  394  2388  100.0  38.54
# 20606  14.62    ...     8139.27  8.4405  0.03  396  2388  100.0  38.46
# 20607  14.62    ...     8142.95  8.5133  0.03  395  2388  100.0  38.60
# 20608  14.62    ...     8141.85  8.4876  0.03  395  2388  100.0  38.55
# 20609  14.62    ...     8138.58  8.5218  0.03  396  2388  100.0  38.62
# 20610  14.62    ...     8138.98  8.5150  0.03  395  2388  100.0  38.54
# 20611  14.62    ...     8139.30  8.5518  0.03  396  2388  100.0  38.52
# 20612  14.62    ...     8140.87  8.4855  0.03  396  2388  100.0  38.41
# 20613  14.62    ...     8144.21  8.5006  0.03  395  2388  100.0  38.49
# 20614  14.62    ...     8142.28  8.4989  0.03  396  2388  100.0  38.44
# 20615  14.62    ...     8142.32  8.4804  0.03  395  2388  100.0  38.60
# 20616  14.62    ...     8138.08  8.4735  0.03  394  2388  100.0  38.51
# 20617  14.62    ...     8140.49  8.5087  0.03  396  2388  100.0  38.67
# 20618  14.62    ...     8139.94  8.4814  0.03  395  2388  100.0  38.36
# 20619  14.62    ...     8139.78  8.4870  0.03  397  2388  100.0  38.65
# 20620  14.62    ...     8142.28  8.5162  0.03  395  2388  100.0  38.42
# 20621  14.62    ...     8143.56  8.5092  0.03  398  2388  100.0  38.39
# 20622  14.62    ...     8143.46  8.4892  0.03  397  2388  100.0  38.56
# 20623  14.62    ...     8142.02  8.5424  0.03  397  2388  100.0  38.47
# 20624  14.62    ...     8139.67  8.5215  0.03  394  2388  100.0  38.38
# 20625  14.62    ...     8142.90  8.5519  0.03  394  2388  100.0  38.14
# 20626  14.62    ...     8137.60  8.4956  0.03  397  2388  100.0  38.49
# 20627  14.62    ...     8136.50  8.5139  0.03  395  2388  100.0  38.30
# 20628  14.62    ...     8141.05  8.5646  0.03  398  2388  100.0  38.44
# 20629  14.62    ...     8139.29  8.5389  0.03  395  2388  100.0  38.29
# 20630  14.62    ...     8137.33  8.5036  0.03  396  2388  100.0  38.37
#
#             25  target_easy     ratio
# 0      23.4190          0.0  0.005208
# 1      23.4236          0.0  0.010417
# 2      23.3442          0.0  0.015625
# 3      23.3739          0.0  0.020833
# 4      23.4044          0.0  0.026042
# 5      23.3669          0.0  0.031250
# 6      23.3774          0.0  0.036458
# 7      23.3106          0.0  0.041667
# 8      23.4066          0.0  0.046875
# 9      23.4694          0.0  0.052083
# 10     23.4787          0.0  0.057292
# 11     23.3660          0.0  0.062500
# 12     23.2757          0.0  0.067708
# 13     23.3826          0.0  0.072917
# 14     23.3500          0.0  0.078125
# 15     23.4550          0.0  0.083333
# 16     23.3319          0.0  0.088542
# 17     23.3987          0.0  0.093750
# 18     23.3464          0.0  0.098958
# 19     23.4220          0.0  0.104167
# 20     23.3101          0.0  0.109375
# 21     23.3792          0.0  0.114583
# 22     23.4562          0.0  0.119792
# 23     23.3696          0.0  0.125000
# 24     23.4288          0.0  0.130208
# 25     23.4149          0.0  0.135417
# 26     23.4472          0.0  0.140625
# 27     23.2841          0.0  0.145833
# 28     23.3597          0.0  0.151042
# 29     23.4110          0.0  0.156250
# ...        ...          ...       ...
# 20601  23.1513          1.0  0.855000
# 20602  23.1922          1.0  0.860000
# 20603  23.1793          1.0  0.865000
# 20604  23.1784          1.0  0.870000
# 20605  23.0713          1.0  0.875000
# 20606  23.1020          1.0  0.880000
# 20607  23.0352          1.0  0.885000
# 20608  23.2252          1.0  0.890000
# 20609  23.1685          1.0  0.895000
# 20610  23.2345          1.0  0.900000
# 20611  23.1774          1.0  0.905000
# 20612  23.1289          1.0  0.910000
# 20613  23.0709          1.0  0.915000
# 20614  23.1229          1.0  0.920000
# 20615  23.2127          1.0  0.925000
# 20616  23.1173          1.0  0.930000
# 20617  23.2308          1.0  0.935000
# 20618  23.0552          1.0  0.940000
# 20619  23.0591          1.0  0.945000
# 20620  23.0603          1.0  0.950000
# 20621  23.1218          1.0  0.955000
# 20622  23.0770          1.0  0.960000
# 20623  23.0230          1.0  0.965000
# 20624  23.1324          1.0  0.970000
# 20625  23.1923          1.0  0.975000
# 20626  22.9735          1.0  0.980000
# 20627  23.1594          1.0  0.985000
# 20628  22.9333          1.0  0.990000
# 20629  23.0640          1.0  0.995000
# 20630  23.0522          1.0  1.000000
#
# [20631 rows x 28 columns]

# %%
# drop the useless columns 0 ,1 ,2, 27

df_drop = df.drop(df.columns[[0, 1]], axis=1)

# drop the nan and get the pure classes

df_1 = df_drop.dropna(axis = 0 , how='any')
df_1 = df_1.sample(20000)
#print df_1

# %%
# store the random dataframe
df_1.to_csv(save_path + 'train_FD001_80_20_com.txt', header = True)
